# %% [markdown]
# # Отчёт по курсам валют

# %%
import requests

# %%
r = requests.get ("https://www.cbr-xml-daily.ru/daily_json.js")

# %%
curs = r.json()['Valute']['GBP']
curs
# Out:
# {'ID': 'R01035',
#  'NumCode': '826',
#  'CharCode': 'GBP',
#  'Nominal': 1,
#  'Name': 'Фунт стерлингов',
#  'Value': 105.4515,
#  'Previous': 104.5009}
